# %% [markdown]
# <a href="https://colab.research.google.com/github/martinezandrea473-hash/Notebook_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento**:
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
# $$Pa=Lt *0.92$$
#
# $$  r=(pa/pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float).(pr)
#Solicitar los litros de aceite obtenidos (Tipo float).(lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

#PROCESO:Calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa / pr) * 100

#SALIDA:Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# Aquí está la explicación de cada línea del código:
#
# ```python
# # ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float).(pr)
# #Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# ```
# Estas líneas son comentarios (indicados por el `#` al principio). Sirven para documentar el código y explicar qué tipo de entrada se espera en las siguientes líneas.
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# *   `input("Ingrese el nombre del lote: ")`: Muestra el mensaje "Ingrese el nombre del lote: " al usuario en la consola y espera a que este escriba algo y presione Enter. El texto ingresado por el usuario es devuelto como una cadena de texto (string).
# *   `nombre = ...`: Asigna la cadena de texto ingresada por el usuario a la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# *   `input("Ingrese el peso de los racimos en kg: ")`: Muestra el mensaje "Ingrese el peso de los racimos en kg: " al usuario y espera su entrada.
# *   `float(...)`: Convierte la cadena de texto (string) que el usuario ingresó en un número de punto flotante (float). Esto es necesario porque el peso puede tener decimales.
# *   `pr = ...`: Asigna este valor de punto flotante a la variable `pr` (peso de los racimos).
#
# ```python
# lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# *   `input("Ingrese la cantidad de aceite crudo obtenido en litros: ")`: Muestra el mensaje "Ingrese la cantidad de aceite crudo obtenido en litros: " al usuario y espera su entrada.
# *   `float(...)`: Convierte la cadena de texto ingresada por el usuario en un número de punto flotante.
# *   `lt = ...`: Asigna este valor de punto flotante a la variable `lt` (litros de aceite).
#
# ```python
# #PROCESO:Calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este es un comentario que indica que las siguientes líneas realizarán los cálculos.
#
# ```python
# pa = lt * 0.92
# ```
# *   `lt * 0.92`: Multiplica la cantidad de litros de aceite (`lt`) por la densidad del aceite (0.92 kg/L) para obtener el peso del aceite en kilogramos.
# *   `pa = ...`: Asigna el resultado de esta multiplicación a la variable `pa` (peso del aceite).
#
# ```python
# r = (pa / pr) * 100
# ```
# *   `pa / pr`: Divide el peso del aceite (`pa`) entre el peso total de los racimos (`pr`) para obtener la proporción de aceite.
# *   `(...) * 100`: Multiplica la proporción por 100 para expresarla como un porcentaje.
# *   `r = ...`: Asigna el resultado final (el porcentaje de rendimiento) a la variable `r`.
#
# ```python
# #SALIDA:Informar el rendimiento del lote
# ```
# Este es un comentario que indica que la siguiente línea mostrará el resultado.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# *   `print(...)`: Muestra información en la consola.
# *   `"El rendimiento del lote"`, `nombre`, `"es del"`, `r`, `"%"`: Estas son las diferentes partes (cadenas de texto y variables) que se concatenarán y se mostrarán en la pantalla, formando una frase completa que informa al usuario sobre el rendimiento calculado para el lote específico.
